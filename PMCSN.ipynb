# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import polars as pl

file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'

# Creiamo il piano di esecuzione con i parametri corretti
df_lazy = pl.scan_csv(
    file_path,
    null_values=["NA"],         # Dice a Polars di trattare le stringhe "NA" come dati mancanti (Null)
    infer_schema_length=10000   # Legge le prime 10.000 righe per capire meglio i tipi di dato
)

# Eseguiamo il collect() solo per le prime 5 righe per verificare che funzioni
print(df_lazy.head(5).collect())
# Out:
# shape: (5, 66)
# ┌───────────┬───────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ tr_build_ ┆ gh_projec ┆ gh_is_pr ┆ gh_pr_cre ┆ … ┆ tr_origin ┆ tr_durati ┆ tr_status ┆ tr_jobs   │
# │ id        ┆ t_name    ┆ ---      ┆ ated_at   ┆   ┆ al_commit ┆ on        ┆ ---       ┆ ---       │
# │ ---       ┆ ---       ┆ bool     ┆ ---       ┆   ┆ ---       ┆ ---       ┆ str       ┆ str       │
# │ i64       ┆ str       ┆          ┆ str       ┆   ┆ str       ┆ i64       ┆           ┆           │
# ╞═══════════╪═══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 3154      ┆ rspec/rsp ┆ false    ┆ null      ┆ … ┆ 029e6972f ┆ 956       ┆ passed    ┆ [3161,    │
# │           ┆ ec-core   ┆          ┆           ┆   ┆ cf719542d ┆           ┆           ┆ 3163,     │
# │           ┆           ┆          ┆           ┆   ┆ eff1b2619 ┆           ┆           ┆ 3160,     │
# │           ┆           ┆          ┆           ┆   ┆ d29…      ┆           ┆           ┆ 3162,     │
# │           ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆ 3164]     │
# │ 3154      ┆ rspec/rsp ┆ false    ┆ null      ┆ … ┆ 029e6972f ┆ 956       ┆ passed    ┆ [3161,    │
# │           ┆ ec-core   ┆          ┆           ┆   ┆ cf719542d ┆           ┆           ┆ 3163,     │
# │           ┆           ┆          ┆           ┆   ┆ eff1b2619 ┆           ┆           ┆ 3160,     │
# │           ┆           ┆          ┆           ┆   ┆ d29…      ┆           ┆           ┆ 3162,     │
# │           ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆ 3164]     │
# │ 3154      ┆ rspec/rsp ┆ false    ┆ null      ┆ … ┆ 029e6972f ┆ 956       ┆ passed    ┆ [3161,    │
# │           ┆ ec-core   ┆          ┆           ┆   ┆ cf719542d ┆           ┆           ┆ 3163,     │
# │           ┆           ┆          ┆           ┆   ┆ eff1b2619 ┆           ┆           ┆ 3160,     │
# │           ┆           ┆          ┆           ┆   ┆ d29…      ┆           ┆           ┆ 3162,     │
# │           ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆ 3164]     │
# │ 3154      ┆ rspec/rsp ┆ false    ┆ null      ┆ … ┆ 029e6972f ┆ 956       ┆ passed    ┆ [3161,    │
# │           ┆ ec-core   ┆          ┆           ┆   ┆ cf719542d ┆           ┆           ┆ 3163,     │
# │           ┆           ┆          ┆           ┆   ┆ eff1b2619 ┆           ┆           ┆ 3160,     │
# │           ┆           ┆          ┆           ┆   ┆ d29…      ┆           ┆           ┆ 3162,     │
# │           ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆ 3164]     │
# │ 3154      ┆ rspec/rsp ┆ false    ┆ null      ┆ … ┆ 029e6972f ┆ 956       ┆ passed    ┆ [3161,    │
# │           ┆ ec-core   ┆          ┆           ┆   ┆ cf719542d ┆           ┆           ┆ 3163,     │
# │           ┆           ┆          ┆           ┆   ┆ eff1b2619 ┆           ┆           ┆ 3160,     │
# │           ┆           ┆          ┆           ┆   ┆ d29…      ┆           ┆           ┆ 3162,     │
# │           ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆ 3164]     │
# └───────────┴───────────┴──────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
import polars as pl

file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'
print("Ricerca del progetto ideale: Filtro strutturale in corso...\n")

# Colonne su cui vogliamo garantire la completezza
colonne_target = [
    'tr_build_id', 'tr_job_id', 'gh_build_started_at',
    'tr_log_setup_time', 'tr_log_buildduration'
]

# 1. Completezza e Distribuzione degli Stati
df_stats = (
    df_lazy
    .group_by("gh_project_name")
    .agg([
        pl.len().alias("totale_job"),
        # Calcolo % stati (Failed, Errored, Canceled)
        ((pl.col("tr_status").eq("failed").sum() / pl.len()) * 100).round(2).alias("%_failed"),
        ((pl.col("tr_status").eq("errored").sum() / pl.len()) * 100).round(2).alias("%_errored"),
        ((pl.col("tr_status").eq("canceled").sum() / pl.len()) * 100).round(2).alias("%_canceled"),
        # Calcolo % record non nulli (media per le colonne critiche)
        (((sum((pl.col(col).is_not_null()).sum() for col in colonne_target)) / (pl.len() * len(colonne_target))) * 100).round(2).alias("score_completezza")
    ])
)

# 2. Variabilità dei Job per Build
df_builds = df_lazy.group_by(["gh_project_name", "tr_build_id"]).agg(pl.len().alias("num_jobs"))
df_variabilita = (
    df_builds
    .group_by("gh_project_name")
    .agg([
        pl.len().alias("totale_builds"),
        pl.col("num_jobs").max().alias("max_jobs_per_build"),
        pl.col("num_jobs").min().alias("min_jobs_per_build"),
        pl.col("num_jobs").std().round(2).alias("std_jobs")
    ])
)

# 3. Unione e Filtraggio Finale
candidati_ideali = (
    df_stats.join(df_variabilita, on="gh_project_name")
    # Filtro 1: Dati robusti (almeno 1000 job, altissima completezza)
    .filter(pl.col("totale_job") >= 1000)
    .filter(pl.col("score_completezza") >= 90.0)
    # Filtro 2: Variabilità arrivi (almeno 5 job in una singola build)
    .filter(pl.col("max_jobs_per_build") >= 5)
    # Filtro 3: Presenza non nulla di stati anomali (tutti maggiori di 0)
    .filter((pl.col("%_failed") > 0) & (pl.col("%_errored") > 0) & (pl.col("%_canceled") > 0))
    # Ordiniamo per completezza e variabilità
    .sort(["score_completezza", "std_jobs"], descending=[True, True])
).collect()

# Estraiamo i nomi dei top 3 progetti
top_3_projects = candidati_ideali["gh_project_name"].head(3).to_list()

with pl.Config(tbl_rows=10):
    print("--- TOP CANDIDATI STRUTTURALI ---")
    print(candidati_ideali.head(5))
# Out:
# Ricerca del progetto ideale: Filtro strutturale in corso...
#
# --- TOP CANDIDATI STRUTTURALI ---
# shape: (5, 10)
# ┌────────────┬───────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ gh_project ┆ totale_jo ┆ %_failed ┆ %_errored ┆ … ┆ totale_bu ┆ max_jobs_ ┆ min_jobs_ ┆ std_jobs │
# │ _name      ┆ b         ┆ ---      ┆ ---       ┆   ┆ ilds      ┆ per_build ┆ per_build ┆ ---      │
# │ ---        ┆ ---       ┆ f64      ┆ f64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ f64      │
# │ str        ┆ u32       ┆          ┆           ┆   ┆ u32       ┆ u32       ┆ u32       ┆          │
# ╞════════════╪═══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ checkstyle ┆ 46889     ┆ 7.1      ┆ 0.77      ┆ … ┆ 2899      ┆ 35        ┆ 1         ┆ 10.14    │
# │ /checkstyl ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆          │
# │ e          ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆          │
# │ xetorthio/ ┆ 3258      ┆ 13.75    ┆ 2.12      ┆ … ┆ 905       ┆ 5         ┆ 2         ┆ 0.5      │
# │ jedis      ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆          │
# │ SonarSourc ┆ 16278     ┆ 3.45     ┆ 18.03     ┆ … ┆ 2278      ┆ 10        ┆ 1         ┆ 2.33     │
# │ e/sonar-ja ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆          │
# │ va         ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆          │
# │ geoserver/ ┆ 6742      ┆ 46.72    ┆ 6.08      ┆ … ┆ 3025      ┆ 6         ┆ 1         ┆ 1.08     │
# │ geoserver  ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆          │
# │ typetools/ ┆ 6305      ┆ 36.49    ┆ 5.42      ┆ … ┆ 2062      ┆ 9         ┆ 1         ┆ 0.49     │
# │ checker-fr ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆          │
# │ amework    ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆          │
# └────────────┴───────────┴──────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
import numpy as np
import scipy.stats as stats
import pandas as pd
import polars as pl

print("\n--- TEST STATISTICO DELLE DISTRIBUZIONI SUI TOP 3 PROGETTI ---")

# Ricarichiamo in Pandas solo i dati dei 3 vincitori forzando i tipi corretti
df_test = (
    pl.scan_csv(file_path, null_values=["NA", ""], infer_schema_length=10000,
        schema_overrides={"tr_log_buildduration": pl.String, "tr_log_setup_time": pl.String})
    .filter(pl.col("gh_project_name").is_in(top_3_projects))
    # --- MODIFICA 1: Aggiungiamo 'tr_status' alla selezione per poter filtrare ---
    .select(["gh_project_name", "tr_build_id", "tr_job_id", "gh_build_started_at", "tr_log_buildduration", "tr_status"])
    .with_columns([
        pl.col("tr_log_buildduration").cast(pl.Float64, strict=False)
    ])
    .drop_nulls()
    .collect().to_pandas()
)

for proj in top_3_projects:
    print(f"\nAnalisi per: {proj}")
    df_proj = df_test[df_test["gh_project_name"] == proj].copy()

    # 1. Test Distribuzione Tempi di Build (Lognormale SOLO sui job ideali)
    # --- MODIFICA 2: Filtriamo i dati isolando solo i job con stato 'passed' ---
    df_passed = df_proj[df_proj["tr_status"] == "passed"]

    build_times = df_passed["tr_log_buildduration"].values
    build_times = build_times[build_times > 0] # Continua a funzionare, ma su un sottoinsieme

    # Fittiamo la lognormale (Rappresenta la durata IDEALE della compilazione)
    shape, loc, scale = stats.lognorm.fit(build_times, floc=0)

    # KS-Test (calcoliamo la statistica D)
    D_build, p_build = stats.kstest(build_times, 'lognorm', args=(shape, loc, scale))
    print(f"  [Build - Solo Passed] Lognormale -> Errore (D): {D_build:.4f} | p-value: {p_build:.4e}")

    # 2. Preparazione Inter-arrivi (TUTTI i job, calcolano il carico reale)
    # Convertiamo le date in modo robusto gestendo vari formati
    df_proj['timestamp'] = pd.to_datetime(df_proj['gh_build_started_at'], format='mixed', utc=True).astype('int64') // 10**9

    # Raggruppiamo per build per avere arrivi puliti
    arrivi = df_proj.groupby('tr_build_id')['timestamp'].min().sort_values().values
    inter_arrivi = np.diff(arrivi)
    inter_arrivi = inter_arrivi[inter_arrivi > 0] # Togliamo arrivi simultanei

    # Fittiamo Esponenziale
    loc_exp, scale_exp = stats.expon.fit(inter_arrivi, floc=0)
    D_arr, p_arr = stats.kstest(inter_arrivi, 'expon', args=(loc_exp, scale_exp))
    print(f"  [Arrivi - Tutti] Esponenziale -> Errore (D): {D_arr:.4f} | p-value: {p_arr:.4e}")
# Out:
# --- TEST STATISTICO DELLE DISTRIBUZIONI SUI TOP 3 PROGETTI ---
#
# Analisi per: checkstyle/checkstyle
#   [Build - Solo Passed] Lognormale -> Errore (D): 0.0546 | p-value: 5.4776e-100
#   [Arrivi - Tutti] Esponenziale -> Errore (D): 0.4268 | p-value: 9.0906e-319
#
# Analisi per: xetorthio/jedis
#   [Build - Solo Passed] Lognormale -> Errore (D): 0.0506 | p-value: 3.8897e-06
#   [Arrivi - Tutti] Esponenziale -> Errore (D): 0.5261 | p-value: 6.8122e-232
#
# Analisi per: SonarSource/sonar-java
#   [Build - Solo Passed] Lognormale -> Errore (D): 0.0280 | p-value: 4.4578e-07
#   [Arrivi - Tutti] Esponenziale -> Errore (D): 0.3691 | p-value: 1.2716e-238

# %%
import polars as pl
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'
PROJECT_NAME = "SonarSource/sonar-java"

print(f"Estrazione dati e generazione grafici per {PROJECT_NAME}...")

# ==========================================
# 1. ESTRAZIONE DATI (Polars)
# ==========================================
df = (
    pl.scan_csv(file_path, null_values=["NA", ""], infer_schema_length=10000,
        schema_overrides={"tr_log_buildduration": pl.String, "tr_log_setup_time": pl.String})
    .filter(pl.col("gh_project_name") == PROJECT_NAME)
    # --- CORREZIONE: Utilizzo di tr_log_setup_time ---
    .select(["tr_build_id", "tr_job_id", "git_trigger_commit", "gh_build_started_at", "tr_status", "tr_log_setup_time", "tr_log_buildduration"])
    .with_columns([
        pl.col("tr_log_setup_time").cast(pl.Float64, strict=False),
        pl.col("tr_log_buildduration").cast(pl.Float64, strict=False),
        (pl.col("gh_build_started_at").str.to_datetime(strict=False).dt.timestamp("ms") / 1000.0).alias("start_ts")
    ])
    .drop_nulls(subset=["tr_log_setup_time", "tr_log_buildduration", "start_ts"])
).collect()

# --- Dati Test (Netto Setup) ---
df_passed = (
    df.filter(pl.col("tr_status") == "passed")
    # --- CORREZIONE: Calcolo usando tr_log_setup_time ---
    .with_columns([(pl.col("tr_log_buildduration") - pl.col("tr_log_setup_time")).alias("test_duration_net")])
)

test_times = df_passed.filter(pl.col("test_duration_net") > 0)["test_duration_net"].to_numpy()
shape_t, loc_t, scale_t = stats.lognorm.fit(test_times, floc=0)
D_test, _ = stats.kstest(test_times, 'lognorm', args=(shape_t, loc_t, scale_t))

# --- Dati Inter-arrivi (Esogeni) ---
df_builds = (
    df.group_by(["tr_build_id", "git_trigger_commit"])
    .agg([
        pl.col("start_ts").min().alias("build_start"),
        ((pl.col("tr_status") == "failed") | (pl.col("tr_status") == "errored")).sum().alias("bad_jobs_count")
    ])
    .with_columns([(pl.col("bad_jobs_count") > 0).alias("is_bad_build")])
    .sort(["git_trigger_commit", "build_start"])
)

df_arrivals = (
    df_builds.with_columns([pl.col("is_bad_build").shift(1).over("git_trigger_commit").alias("prev_build_bad")])
    .with_columns([(pl.col("prev_build_bad").is_null() | (pl.col("prev_build_bad") == False)).alias("is_new_arrival")])
    .filter(pl.col("is_new_arrival") == True)
    .sort("build_start")
)

inter_arrivals = np.diff(df_arrivals["build_start"].to_numpy())
inter_arrivals = inter_arrivals[inter_arrivals > 0]
loc_a, scale_a = stats.expon.fit(inter_arrivals, floc=0)
D_arr, _ = stats.kstest(inter_arrivals, 'expon', args=(loc_a, scale_a))

# ==========================================
# 2. CREAZIONE DASHBOARD GRAFICA
# ==========================================
sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(16, 11))

# Limiti per la visualizzazione pulita
test_plot = test_times[test_times < np.percentile(test_times, 98)]
arr_plot = inter_arrivals[inter_arrivals < np.percentile(inter_arrivals, 95)]

# --- PLOT 1: Grafico Cartesiano - Tempi di Test (Sequenza) ---
axes[0, 0].scatter(range(len(test_times)), test_times, color='#3498db', alpha=0.3, s=8, edgecolor='none')
axes[0, 0].set_title("Sequenza Tempi di Test (Netto Setup)", fontsize=13, fontweight='bold')
axes[0, 0].set_xlabel("Indice Job Passed", fontsize=11)
axes[0, 0].set_ylabel("Durata Test (Secondi)", fontsize=11)

# --- PLOT 2: Grafico Cartesiano - Inter-arrivi (Sequenza) ---
axes[0, 1].scatter(range(len(inter_arrivals)), inter_arrivals, color='#e74c3c', alpha=0.3, s=8, edgecolor='none')
axes[0, 1].set_title("Sequenza Inter-arrivi (Solo Traffico Esogeno)", fontsize=13, fontweight='bold')
axes[0, 1].set_xlabel("Indice Build", fontsize=11)
axes[0, 1].set_ylabel("Inter-arrivo (Secondi)", fontsize=11)
axes[0, 1].set_yscale('log')

# --- PLOT 3: Grafico a Barre (Istogramma) - Fitting Lognormale ---
axes[1, 0].hist(test_plot, bins=50, density=True, alpha=0.6, color='#2980b9', edgecolor='white', label='Dati (Top 98%)')
x_test = np.linspace(0, max(test_plot), 200)
axes[1, 0].plot(x_test, stats.lognorm.pdf(x_test, shape_t, loc_t, scale_t), 'k--', lw=2.5, label=f'Fit Lognormale\n(D={D_test:.4f})')
axes[1, 0].set_title("Distribuzione Tempi di Test vs Curva Lognormale", fontsize=13, fontweight='bold')
axes[1, 0].set_xlabel("Durata Test (Secondi)", fontsize=11)
axes[1, 0].set_ylabel("Densità", fontsize=11)
axes[1, 0].legend()

# --- PLOT 4: Grafico a Barre (Istogramma) - Fitting Esponenziale ---
axes[1, 1].hist(arr_plot, bins=50, density=True, alpha=0.6, color='#c0392b', edgecolor='white', label='Dati (Top 95%)')
x_arr = np.linspace(0, max(arr_plot), 200)
axes[1, 1].plot(x_arr, stats.expon.pdf(x_arr, loc_a, scale_a), 'k--', lw=2.5, label=f'Fit Esponenziale\n(D={D_arr:.4f})')
axes[1, 1].set_title("Distribuzione Inter-arrivi vs Curva Esponenziale", fontsize=13, fontweight='bold')
axes[1, 1].set_xlabel("Inter-arrivo (Secondi)", fontsize=11)
axes[1, 1].set_ylabel("Densità", fontsize=11)
axes[1, 1].legend()

plt.tight_layout()
plt.show()
# Out:
# Estrazione dati e generazione grafici per SonarSource/sonar-java...

# %%
print("--- PARAMETRI LOGNORMALE (Fase 2: Tempi di Test Netti) ---")
print(f"Shape (sigma):  {shape_t:.4f}")
print(f"Loc (shift):    {loc_t:.4f}")
print(f"Scale:          {scale_t:.4f}")
print(f"Mu (ln(scale)): {np.log(scale_t):.4f}")

print("\n--- PARAMETRI ESPONENZIALE (Traffico Esogeno Inter-arrivi) ---")
print(f"Loc (shift):          {loc_a:.4f}")
print(f"Scale (Media, 1/λ): {scale_a:.4f}")
print(f"Tasso λ (Arrivi/sec): {1/scale_a:.6f}")
# Out:
# --- PARAMETRI LOGNORMALE (Fase 2: Tempi di Test Netti) ---
# Shape (sigma):  0.5295
# Loc (shift):    0.0000
# Scale:          383.9175
# Mu (ln(scale)): 5.9504
#
# --- PARAMETRI ESPONENZIALE (Traffico Esogeno Inter-arrivi) ---
# Loc (shift):          0.0000
# Scale (Media, 1/λ): 22042.3060
# Tasso λ (Arrivi/sec): 0.000045

# %%
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'
PROJECT_NAME = "SonarSource/sonar-java"

print(f"Estrazione tempi di setup per {PROJECT_NAME}...")

# ==========================================
# 1. ESTRAZIONE DATI SETUP
# ==========================================
df_setup = (
    pl.scan_csv(file_path, null_values=["NA", ""], infer_schema_length=10000,
        schema_overrides={"tr_log_buildduration": pl.String, "tr_log_setup_time": pl.String})
    .filter(pl.col("gh_project_name") == PROJECT_NAME)
    .select(["tr_log_setup_time"])
    .with_columns(pl.col("tr_log_setup_time").cast(pl.Float64, strict=False))
    .drop_nulls()
    # Consideriamo solo i tempi di setup validi (maggiori di zero)
    .filter(pl.col("tr_log_setup_time") > 0)
).collect()

setup_times = df_setup["tr_log_setup_time"].to_numpy()

print(f"Trovati {len(setup_times)} tempi di setup validi.")

# ==========================================
# 2. CREAZIONE BOX PLOT VERTICALE
# ==========================================
sns.set_theme(style="whitegrid")
plt.figure(figsize=(6, 8))

# Filtro visivo per non schiacciare il box plot a causa degli outlier infrastrutturali
percentile_limite = 98
limite_visivo = np.percentile(setup_times, percentile_limite)
setup_times_plot = setup_times[setup_times < limite_visivo]

# Creazione del Box Plot
sns.boxplot(
    y=setup_times_plot,
    color="#f1c40f",       # Un giallo/oro per distinguere il setup dal test
    fliersize=4,           # Dimensione dei punti outlier
    linewidth=1.5,
    width=0.4              # Larghezza della scatola
)

plt.title(f"Box Plot dei Tempi di Setup\n(Filtro visivo al {percentile_limite}° percentile)", fontsize=13, fontweight='bold')
plt.ylabel("Tempo di Setup (Secondi)", fontsize=11)

# Aggiungiamo qualche statistica testuale sul grafico per comodità
mediana = np.median(setup_times)
media = np.mean(setup_times)
plt.text(
    0.25, mediana,
    f"Mediana: {mediana:.1f}s\nMedia: {media:.1f}s",
    verticalalignment='center',
    bbox=dict(facecolor='white', alpha=0.8, edgecolor='gray', boxstyle='round,pad=0.5')
)

plt.tight_layout()
plt.show()
# Out:
# Estrazione tempi di setup per SonarSource/sonar-java...
# Trovati 15426 tempi di setup validi.

# %%
import polars as pl

file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'
PROJECT_NAME = "SonarSource/sonar-java"

print(f"--- FREQUENZA DEI TEMPI DI SETUP PER {PROJECT_NAME} ---\n")

# 1. Estrazione dati (come prima)
df_setup = (
    pl.scan_csv(file_path, null_values=["NA", ""], infer_schema_length=10000,
        schema_overrides={"tr_log_buildduration": pl.String, "tr_log_setup_time": pl.String})
    .filter(pl.col("gh_project_name") == PROJECT_NAME)
    .select(["tr_log_setup_time"])
    .with_columns(pl.col("tr_log_setup_time").cast(pl.Float64, strict=False))
    .drop_nulls()
    .filter(pl.col("tr_log_setup_time") > 0)
).collect()

total_setups = df_setup.height

# 2. Raggruppamento e calcolo percentuali
df_freq = (
    df_setup
    .group_by("tr_log_setup_time")
    .agg(pl.len().alias("conteggio"))
    .with_columns([
        ((pl.col("conteggio") / total_setups) * 100).round(4).alias("percentuale_%")
    ])
    # Ordiniamo per frequenza per vedere subito i tempi più ricorrenti
    .sort("conteggio", descending=True)
)

print(f"Totale record di setup validi: {total_setups}")
print(f"Valori unici di setup trovati: {df_freq.height}\n")

print("Tabella delle occorrenze (Top 30 valori più frequenti):")
# Aumentiamo il limite di visualizzazione di Polars per questa cella
pl.Config.set_tbl_rows(30)
print(df_freq.head(30))
# Out:
# --- FREQUENZA DEI TEMPI DI SETUP PER SonarSource/sonar-java ---
#
# Totale record di setup validi: 15426
# Valori unici di setup trovati: 28
#
# Tabella delle occorrenze (Top 30 valori più frequenti):
# shape: (28, 3)
# ┌───────────────────┬───────────┬───────────────┐
# │ tr_log_setup_time ┆ conteggio ┆ percentuale_% │
# │ ---               ┆ ---       ┆ ---           │
# │ f64               ┆ u32       ┆ f64           │
# ╞═══════════════════╪═══════════╪═══════════════╡
# │ 1.0               ┆ 7576      ┆ 49.1119       │
# │ 2.0               ┆ 4112      ┆ 26.6563       │
# │ 3.0               ┆ 1781      ┆ 11.5454       │
# │ 4.0               ┆ 1412      ┆ 9.1534        │
# │ 5.0               ┆ 195       ┆ 1.2641        │
# │ 6.0               ┆ 114       ┆ 0.739         │
# │ 7.0               ┆ 53        ┆ 0.3436        │
# │ 8.0               ┆ 34        ┆ 0.2204        │
# │ 10.0              ┆ 31        ┆ 0.201         │
# │ 9.0               ┆ 31        ┆ 0.201         │
# │ 11.0              ┆ 18        ┆ 0.1167        │
# │ 12.0              ┆ 10        ┆ 0.0648        │
# │ 13.0              ┆ 10        ┆ 0.0648        │
# │ 15.0              ┆ 9         ┆ 0.0583        │
# │ 19.0              ┆ 8         ┆ 0.0519        │
# │ 14.0              ┆ 5         ┆ 0.0324        │
# │ 16.0              ┆ 5         ┆ 0.0324        │
# │ 18.0              ┆ 4         ┆ 0.0259        │
# │ 17.0              ┆ 4         ┆ 0.0259        │
# │ 21.0              ┆ 3         ┆ 0.0194        │
# │ 23.0              ┆ 3         ┆ 0.0194        │
# │ 20.0              ┆ 2         ┆ 0.013         │
# │ 94.0              ┆ 1         ┆ 0.0065        │
# │ 67.0              ┆ 1         ┆ 0.0065        │
# │ 76.0              ┆ 1         ┆ 0.0065        │
# │ 46.0              ┆ 1         ┆ 0.0065        │
# │ 28.0              ┆ 1         ┆ 0.0065        │
# │ 34.0              ┆ 1         ┆ 0.0065        │
# └───────────────────┴───────────┴───────────────┘

# %%
import polars as pl
import pandas as pd
import numpy as np
import scipy.stats as stats

PROJECT_NAME = "SonarSource/sonar-java"
file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'

print("--- ESTRAZIONE TEMPI SEPARATI: SETUP vs TEST (NETTO) ---")

# 1. Estrazione dati con la colonna tr_setup_time
df_proj = (
    pl.scan_csv(file_path, null_values=["NA", ""], infer_schema_length=10000,
        schema_overrides={"tr_log_buildduration": pl.String, "tr_log_setup_time": pl.String})
    .filter(pl.col("gh_project_name") == PROJECT_NAME)
    .select(["tr_build_id", "tr_status", "tr_log_setup_time", "tr_log_buildduration"])
    .with_columns([
        pl.col("tr_log_setup_time").cast(pl.Float64, strict=False),
        pl.col("tr_log_buildduration").cast(pl.Float64, strict=False)
    ])
    .drop_nulls()
    # Calcoliamo la durata netta della compilazione/test
    .with_columns([
        (pl.col("tr_log_buildduration") - pl.col("tr_log_setup_time")).alias("test_duration")
    ])
    # Pulizia: teniamo solo i record in cui entrambe le fasi hanno richiesto tempo
    .filter((pl.col("tr_log_setup_time") > 0) & (pl.col("test_duration") > 0))
    .collect().to_pandas()
)

# 2. Distribuzione del SETUP (Calcolata su TUTTI i job)
setup_times = df_proj["tr_log_setup_time"].values
shape_s, loc_s, scale_s = stats.lognorm.fit(setup_times, floc=0)
D_setup, p_setup = stats.kstest(setup_times, 'lognorm', args=(shape_s, loc_s, scale_s))

# 3. Distribuzione del TEST (Calcolata SOLO sui job 'PASSED')
df_passed = df_proj[df_proj["tr_status"] == "passed"]
test_times = df_passed["test_duration"].values
shape_t, loc_t, scale_t = stats.lognorm.fit(test_times, floc=0)
D_test, p_test = stats.kstest(test_times, 'lognorm', args=(shape_t, loc_t, scale_t))

print(f"\n[FASE 1: SETUP] (Campioni: {len(setup_times)})")
print(f"  Lognormale -> Mu (ln scale): {np.log(scale_s):.4f} | Sigma (shape): {shape_s:.4f}")
print(f"  Media Empirica: {np.mean(setup_times):.2f} secondi")
print(f"  Errore KS (D): {D_setup:.4f}")

print(f"\n[FASE 2: TEST IDEALE NETTO] (Campioni: {len(test_times)})")
print(f"  Lognormale -> Mu (ln scale): {np.log(scale_t):.4f} | Sigma (shape): {shape_t:.4f}")
print(f"  Media Empirica: {np.mean(test_times):.2f} secondi")
print(f"  Errore KS (D): {D_test:.4f}")
# Out:
# --- ESTRAZIONE TEMPI SEPARATI: SETUP vs TEST (NETTO) ---
#
# [FASE 1: SETUP] (Campioni: 9883)
#   Lognormale -> Mu (ln scale): 0.3241 | Sigma (shape): 0.4918
#   Media Empirica: 1.65 secondi
#   Errore KS (D): 0.3750
#
# [FASE 2: TEST IDEALE NETTO] (Campioni: 9078)
#   Lognormale -> Mu (ln scale): 5.9545 | Sigma (shape): 0.5316
#   Media Empirica: 440.08 secondi
#   Errore KS (D): 0.0307

# %%
import polars as pl

file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'
PROJECT_NAME = "SonarSource/sonar-java"

print(f"Estrazione dei record per commit trigger sul progetto: {PROJECT_NAME}...\n")

# Creazione della query con LazyFrame per ottimizzare la RAM
df_commits = (
    pl.scan_csv(
        file_path,
        null_values=["NA", ""],
        infer_schema_length=10000
    )
    .filter(pl.col("gh_project_name") == PROJECT_NAME)

    # Raggruppiamo per l'hash del commit
    .group_by("git_trigger_commit")
    .agg([
        # Conta il numero totale di record (job) scatenati da questo commit
        pl.len().alias("totale_job"),

        # Conta quante build distinte sono state generate
        pl.col("tr_build_id").n_unique().alias("build_uniche")
    ])

    # Ordiniamo in modo decrescente per vedere i commit più "pesanti"
    .sort("totale_job", descending=True)
).collect()

# Stampa dei risultati
with pl.Config(tbl_rows=20):
    print("--- TOP 20 COMMIT PER NUMERO DI JOB GENERATI ---")
    print(df_commits.head(20))

# Stampa del riepilogo generale
print(f"\nNumero totale di commit unici (trigger) trovati: {df_commits.height}")
# Out:
# Estrazione dei record per commit trigger sul progetto: SonarSource/sonar-java...
#
# --- TOP 20 COMMIT PER NUMERO DI JOB GENERATI ---
# shape: (20, 3)
# ┌─────────────────────────────────┬────────────┬──────────────┐
# │ git_trigger_commit              ┆ totale_job ┆ build_uniche │
# │ ---                             ┆ ---        ┆ ---          │
# │ str                             ┆ u32        ┆ u32          │
# ╞═════════════════════════════════╪════════════╪══════════════╡
# │ ec579aff0ea63c2ab37006e926f4e8… ┆ 126        ┆ 14           │
# │ 445b488bcdd30dc45b17420ceb888a… ┆ 90         ┆ 10           │
# │ 4d6a2f3d81f946032941d88b17a92a… ┆ 81         ┆ 9            │
# │ d0a7c1f35a59b6956222fd08f12d86… ┆ 72         ┆ 9            │
# │ 717c052673ad6e79b35522d423b9f9… ┆ 72         ┆ 9            │
# │ 830d17cb913b543d4d20ff23edb4ee… ┆ 70         ┆ 7            │
# │ 90411d927d27a33caa8f1b0ab22831… ┆ 64         ┆ 8            │
# │ 0de67703b4dfd8b857e4eb89e5d361… ┆ 64         ┆ 8            │
# │ 56513b8ce2eb1e9a21c09ee76cdc70… ┆ 60         ┆ 6            │
# │ bf716a45bac2c754238f9d87ed305d… ┆ 56         ┆ 7            │
# │ a32b02316038fb433a83c99c9ff873… ┆ 56         ┆ 7            │
# │ 54620211956d1abcc7af3be3621847… ┆ 56         ┆ 7            │
# │ 4adfce80a60a1feb2f5f729aae9edb… ┆ 56         ┆ 7            │
# │ ba0eac2bd7fba43759e9fb4c6700c7… ┆ 49         ┆ 7            │
# │ 250281f153fafe110e4513d9798c2e… ┆ 49         ┆ 7            │
# │ d60e18fb163918ba68f7be56093067… ┆ 45         ┆ 5            │
# │ dc347caf49767bab0e1cd05ff0ae78… ┆ 42         ┆ 6            │
# │ c303b51c6cf13dfba6821b0a384ab3… ┆ 42         ┆ 6            │
# │ fde8566ee2f97987221dc238b49276… ┆ 40         ┆ 4            │
# │ dd99210a770439ab06d8ada3d4df75… ┆ 40         ┆ 5            │
# └─────────────────────────────────┴────────────┴──────────────┘
#
# Numero totale di commit unici (trigger) trovati: 1176

# %%
import polars as pl

file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'
PROJECT_NAME = "SonarSource/sonar-java"

print(f"Analisi dei commit e degli stati dei job per il progetto: {PROJECT_NAME}...\n")

df_commits = (
    pl.scan_csv(
        file_path,
        null_values=["NA", ""],
        infer_schema_length=10000
    )
    .filter(pl.col("gh_project_name") == PROJECT_NAME)

    # Raggruppiamo sempre per l'hash del commit
    .group_by("git_trigger_commit")
    .agg([
        # Metriche generali
        pl.len().alias("totale_job"),
        pl.col("tr_build_id").n_unique().alias("build_uniche"),

        # Conteggio specifico per ogni stato
        (pl.col("tr_status") == "passed").sum().alias("job_passed"),
        (pl.col("tr_status") == "failed").sum().alias("job_failed"),
        (pl.col("tr_status") == "canceled").sum().alias("job_canceled"),
        (pl.col("tr_status") == "errored").sum().alias("job_errored")
    ])

    # Ordiniamo in modo decrescente per vedere i commit che hanno lavorato di più
    .sort("totale_job", descending=True)
).collect()

# Stampa dei risultati
with pl.Config(tbl_rows=20):
    print("--- TOP 20 COMMIT PER NUMERO DI JOB CON DETTAGLIO STATI ---")
    print(df_commits.head(20))

print(f"\nNumero totale di commit unici (trigger) trovati: {df_commits.height}")
# Out:
# Analisi dei commit e degli stati dei job per il progetto: SonarSource/sonar-java...
#
# --- TOP 20 COMMIT PER NUMERO DI JOB CON DETTAGLIO STATI ---
# shape: (20, 7)
# ┌───────────────┬────────────┬──────────────┬────────────┬────────────┬──────────────┬─────────────┐
# │ git_trigger_c ┆ totale_job ┆ build_uniche ┆ job_passed ┆ job_failed ┆ job_canceled ┆ job_errored │
# │ ommit         ┆ ---        ┆ ---          ┆ ---        ┆ ---        ┆ ---          ┆ ---         │
# │ ---           ┆ u32        ┆ u32          ┆ u32        ┆ u32        ┆ u32          ┆ u32         │
# │ str           ┆            ┆              ┆            ┆            ┆              ┆             │
# ╞═══════════════╪════════════╪══════════════╪════════════╪════════════╪══════════════╪═════════════╡
# │ ec579aff0ea63 ┆ 126        ┆ 14           ┆ 126        ┆ 0          ┆ 0            ┆ 0           │
# │ c2ab37006e926 ┆            ┆              ┆            ┆            ┆              ┆             │
# │ f4e8…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 445b488bcdd30 ┆ 90         ┆ 10           ┆ 90         ┆ 0          ┆ 0            ┆ 0           │
# │ dc45b17420ceb ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 888a…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 4d6a2f3d81f94 ┆ 81         ┆ 9            ┆ 54         ┆ 0          ┆ 0            ┆ 27          │
# │ 6032941d88b17 ┆            ┆              ┆            ┆            ┆              ┆             │
# │ a92a…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 717c052673ad6 ┆ 72         ┆ 9            ┆ 72         ┆ 0          ┆ 0            ┆ 0           │
# │ e79b35522d423 ┆            ┆              ┆            ┆            ┆              ┆             │
# │ b9f9…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ d0a7c1f35a59b ┆ 72         ┆ 9            ┆ 72         ┆ 0          ┆ 0            ┆ 0           │
# │ 6956222fd08f1 ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 2d86…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 830d17cb913b5 ┆ 70         ┆ 7            ┆ 60         ┆ 0          ┆ 0            ┆ 10          │
# │ 43d4d20ff23ed ┆            ┆              ┆            ┆            ┆              ┆             │
# │ b4ee…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 90411d927d27a ┆ 64         ┆ 8            ┆ 64         ┆ 0          ┆ 0            ┆ 0           │
# │ 33caa8f1b0ab2 ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 2831…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 0de67703b4dfd ┆ 64         ┆ 8            ┆ 64         ┆ 0          ┆ 0            ┆ 0           │
# │ 8b857e4eb89e5 ┆            ┆              ┆            ┆            ┆              ┆             │
# │ d361…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 56513b8ce2eb1 ┆ 60         ┆ 6            ┆ 50         ┆ 0          ┆ 0            ┆ 10          │
# │ e9a21c09ee76c ┆            ┆              ┆            ┆            ┆              ┆             │
# │ dc70…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ a32b02316038f ┆ 56         ┆ 7            ┆ 48         ┆ 0          ┆ 0            ┆ 8           │
# │ b433a83c99c9f ┆            ┆              ┆            ┆            ┆              ┆             │
# │ f873…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 4adfce80a60a1 ┆ 56         ┆ 7            ┆ 56         ┆ 0          ┆ 0            ┆ 0           │
# │ feb2f5f729aae ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 9edb…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 54620211956d1 ┆ 56         ┆ 7            ┆ 48         ┆ 0          ┆ 0            ┆ 8           │
# │ abcc7af3be362 ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 1847…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ bf716a45bac2c ┆ 56         ┆ 7            ┆ 48         ┆ 0          ┆ 0            ┆ 8           │
# │ 754238f9d87ed ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 305d…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 250281f153faf ┆ 49         ┆ 7            ┆ 35         ┆ 14         ┆ 0            ┆ 0           │
# │ e110e4513d979 ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 8c2e…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ ba0eac2bd7fba ┆ 49         ┆ 7            ┆ 49         ┆ 0          ┆ 0            ┆ 0           │
# │ 43759e9fb4c67 ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 00c7…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ d60e18fb16391 ┆ 45         ┆ 5            ┆ 36         ┆ 0          ┆ 0            ┆ 9           │
# │ 8ba68f7be5609 ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 3067…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ dc347caf49767 ┆ 42         ┆ 6            ┆ 28         ┆ 0          ┆ 0            ┆ 14          │
# │ bab0e1cd05ff0 ┆            ┆              ┆            ┆            ┆              ┆             │
# │ ae78…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ c303b51c6cf13 ┆ 42         ┆ 6            ┆ 42         ┆ 0          ┆ 0            ┆ 0           │
# │ dfba6821b0a38 ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 4ab3…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 836dfb3599ced ┆ 40         ┆ 4            ┆ 40         ┆ 0          ┆ 0            ┆ 0           │
# │ ba52c9101f168 ┆            ┆              ┆            ┆            ┆              ┆             │
# │ b3b5…         ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 113158f5e90e4 ┆ 40         ┆ 4            ┆ 40         ┆ 0          ┆ 0            ┆ 0           │
# │ b9a88dae2c5cc ┆            ┆              ┆            ┆            ┆              ┆             │
# │ 8e16…         ┆            ┆              ┆            ┆            ┆              ┆             │
# └───────────────┴────────────┴──────────────┴────────────┴────────────┴──────────────┴─────────────┘
#
# Numero totale di commit unici (trigger) trovati: 1176

# %%
import json

# ... (codice precedente per calcolare df_commits) ...

# 1. Convertiamo il DataFrame Polars in una stringa JSON riga per riga
json_string = df_commits.write_json()

# 2. Formattiamo la stringa con un'indentazione di 4 spazi per una facile lettura
json_formattato = json.dumps(json.loads(json_string), indent=4)

print("\n--- RISULTATO IN FORMATO JSON ---")
print(json_formattato)
# Out:
# --- RISULTATO IN FORMATO JSON ---
# [
#     {
#         "git_trigger_commit": "ec579aff0ea63c2ab37006e926f4e83e5cd13ea4",
#         "totale_job": 126,
#         "build_uniche": 14,
#         "job_passed": 126,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "445b488bcdd30dc45b17420ceb888a15032ad5ef",
#         "totale_job": 90,
#         "build_uniche": 10,
#         "job_passed": 90,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "4d6a2f3d81f946032941d88b17a92a0fe04a9218",
#         "totale_job": 81,
#         "build_uniche": 9,
#         "job_passed": 54,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 27
#     },
#     {
#         "git_trigger_commit": "717c052673ad6e79b35522d423b9f979441492dc",
#         "totale_job": 72,
#         "build_uniche": 9,
#         "job_passed": 72,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "d0a7c1f35a59b6956222fd08f12d86f2fe141337",
#         "totale_job": 72,
#         "build_uniche": 9,
#         "job_passed": 72,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "830d17cb913b543d4d20ff23edb4eea6bdec3f1b",
#         "totale_job": 70,
#         "build_uniche": 7,
#         "job_passed": 60,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "90411d927d27a33caa8f1b0ab228312f87f209c8",
#         "totale_job": 64,
#         "build_uniche": 8,
#         "job_passed": 64,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "0de67703b4dfd8b857e4eb89e5d361d864ed1e3b",
#         "totale_job": 64,
#         "build_uniche": 8,
#         "job_passed": 64,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "56513b8ce2eb1e9a21c09ee76cdc70248ad58dec",
#         "totale_job": 60,
#         "build_uniche": 6,
#         "job_passed": 50,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "a32b02316038fb433a83c99c9ff8738af1f499c3",
#         "totale_job": 56,
#         "build_uniche": 7,
#         "job_passed": 48,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "4adfce80a60a1feb2f5f729aae9edb34a103bb13",
#         "totale_job": 56,
#         "build_uniche": 7,
#         "job_passed": 56,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "54620211956d1abcc7af3be362184753dac02cd7",
#         "totale_job": 56,
#         "build_uniche": 7,
#         "job_passed": 48,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "bf716a45bac2c754238f9d87ed305d03ae36867d",
#         "totale_job": 56,
#         "build_uniche": 7,
#         "job_passed": 48,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "250281f153fafe110e4513d9798c2e5b09e2459a",
#         "totale_job": 49,
#         "build_uniche": 7,
#         "job_passed": 35,
#         "job_failed": 14,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "ba0eac2bd7fba43759e9fb4c6700c77cae40c20b",
#         "totale_job": 49,
#         "build_uniche": 7,
#         "job_passed": 49,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "d60e18fb163918ba68f7be56093067138c73aa11",
#         "totale_job": 45,
#         "build_uniche": 5,
#         "job_passed": 36,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "dc347caf49767bab0e1cd05ff0ae7812cc148236",
#         "totale_job": 42,
#         "build_uniche": 6,
#         "job_passed": 28,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 14
#     },
#     {
#         "git_trigger_commit": "c303b51c6cf13dfba6821b0a384ab30fe6a989ab",
#         "totale_job": 42,
#         "build_uniche": 6,
#         "job_passed": 42,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "836dfb3599cedba52c9101f168b3b5d4d7d67b78",
#         "totale_job": 40,
#         "build_uniche": 4,
#         "job_passed": 40,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "113158f5e90e4b9a88dae2c5cc8e168a6c2ae7c1",
#         "totale_job": 40,
#         "build_uniche": 4,
#         "job_passed": 40,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "787504467c5a2aec5958b9c8a35df7843b8ade5c",
#         "totale_job": 40,
#         "build_uniche": 5,
#         "job_passed": 40,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "2294b19662545cf487bee1504ea4534aaa23dcf4",
#         "totale_job": 40,
#         "build_uniche": 5,
#         "job_passed": 32,
#         "job_failed": 0,
#         "job_canceled": 8,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "fcb3475811a89be8ac6150fa00cfd5882dcda968",
#         "totale_job": 40,
#         "build_uniche": 4,
#         "job_passed": 10,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 30
#     },
#     {
#         "git_trigger_commit": "6206da8569b3a638d23560e130c2b61dba238dc2",
#         "totale_job": 40,
#         "build_uniche": 4,
#         "job_passed": 20,
#         "job_failed": 10,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "a09ebca029964cb1c08c7aec919c476744722610",
#         "totale_job": 40,
#         "build_uniche": 5,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 16
#     },
#     {
#         "git_trigger_commit": "817cec1ddf12389ac1a09dbec02dc4e39067a24a",
#         "totale_job": 40,
#         "build_uniche": 4,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 20
#     },
#     {
#         "git_trigger_commit": "24c6c2197b6947f376c7a8a4682c6f732e2158bc",
#         "totale_job": 40,
#         "build_uniche": 5,
#         "job_passed": 40,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "46d1f4ba79f5dd32be23308707dbbccf3661d232",
#         "totale_job": 40,
#         "build_uniche": 5,
#         "job_passed": 40,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "2e775062ff9a42eeff6d62e7fc794f9dfdefbdf4",
#         "totale_job": 40,
#         "build_uniche": 5,
#         "job_passed": 32,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "31123133c97c6ca33dcda48c0d2b5b0e615a750e",
#         "totale_job": 40,
#         "build_uniche": 5,
#         "job_passed": 32,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "dd99210a770439ab06d8ada3d4df7539f2e91ebc",
#         "totale_job": 40,
#         "build_uniche": 5,
#         "job_passed": 32,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "fde8566ee2f97987221dc238b4927632cd255a50",
#         "totale_job": 40,
#         "build_uniche": 4,
#         "job_passed": 30,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "40ea0af5e3048cdcd10167958d9f19e5051357f9",
#         "totale_job": 40,
#         "build_uniche": 5,
#         "job_passed": 40,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "76a7f5b02e60d2cecaec45fd1f745fbc19ca7dc1",
#         "totale_job": 40,
#         "build_uniche": 5,
#         "job_passed": 40,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "87e0ff297057996abee604124d6390a36b52a2fb",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "242e97bf2a377697c77a50f3341003aeed5946da",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "3e5fd73fe292e7023958d9cbd95227ddaa292215",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "703ce143610d1aeafb9cce4bd2ab26958ea2a969",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 36,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "b1f3fc8283aeed14ed036762b0cebd3fe9594359",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 9,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "420cbd62a834f0a4a8aa43950c0293f366099767",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "94c8d8078ebe238f4acd9963a4e2ecd63f9a7908",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "f6e7968f478d96e07e5df0fd2d313026d4ef8305",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "6c3a23d73f68d55dea801358a46cee1b0ae3b282",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 9,
#         "job_failed": 9,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "46ca115b2b0cb491b9b2e64057d653c59fdc5407",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 36,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "f792e70aea36b94eeff3917e2135949dd2f78f12",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 36,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "6161aec126dd69e7f6664439f1bfb865059fedd8",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 36,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "83cdbc66b24949d4f5875d4b8655deced932da86",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 36,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "53a0d5fc44178349a297198689de098eba7e5c2c",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 36,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "bfdb98a42aba6b86102110c5d10816bdc2ee6571",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "586b866ca864fb70b5bdbcc67ba0b71000087b9d",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 18,
#         "job_failed": 9,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "fbc17379490297afe507e58b1a7de3f6029285e6",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "2659b9df3301266efb978b53564a2b79df98a75d",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 36,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "f6a71be6f6b2c8a44eaae17d58a4e22cc1f06f89",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "bfa2ec324c163c3b37c4a3fb1fe75352b0367645",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 36,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "c1fd2054d09d4141546d8ac9774b62c19be052d7",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "19752ec7517db4689c4b1b5ceeb6abddfd90f750",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 18,
#         "job_failed": 9,
#         "job_canceled": 9,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "44800b297ec7209a02055d27269cd5388d11549b",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "5b9e1bbb2a8f6d73e2b1cd62e45d7ea6f2ba0095",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 9,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "1d8135b5abb219ea9bddabf3084d4730219dcc9c",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 18,
#         "job_failed": 9,
#         "job_canceled": 9,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "d32fd99d13c79b0a58535a593240ed290def95e8",
#         "totale_job": 36,
#         "build_uniche": 4,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "ab3b7b4f0e63aec24313ee5dada1f60eff742ed8",
#         "totale_job": 35,
#         "build_uniche": 5,
#         "job_passed": 35,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "bc1040caa1d5eaa5cfc5bf2a2ba39805cdf09feb",
#         "totale_job": 35,
#         "build_uniche": 5,
#         "job_passed": 28,
#         "job_failed": 7,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "8dfa55c97deee0378faad2ea576dce5ee9a29229",
#         "totale_job": 35,
#         "build_uniche": 5,
#         "job_passed": 28,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 7
#     },
#     {
#         "git_trigger_commit": "f28c423b5a1fb47bd0f5e41f1a87e8dc532b61d8",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 32,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "34f7cfb372e3ae9b5ad5600047c46a801d94b1a7",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 32,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "a8a73be3eada7ca2464f3b8394f8abd9d284857d",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "405c44f4648e178eb89ed7d861e8e28cb64f973e",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 16,
#         "job_failed": 8,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "32c2e902e8c780b0fae6e1d947b2c596458288eb",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "16dc8e8322c24fde141ff5cb24f634fed4a73c2a",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 32,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "f978f2f105ba513cd5f7957209b555667001204a",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "ad904ed7070f8be37ce9a600be0a56f3831d5119",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 32,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "5ef99f8eee3302cf236dd250e85caebf2a3781ad",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 16,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 16
#     },
#     {
#         "git_trigger_commit": "320e07e04c6dbb58c0b38f15e74701bd6ab2947c",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "d5b3a84bc6a40761f589d95691e2126d312c6207",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "010a9f9b7c60050f1c669f14831e02a488d0b2d0",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 32,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "93d9fd8400d7370cf4f244d16a1829004183a22e",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 32,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "c2e2d04191cdb3beca6deca6b3352aa3ce728a9a",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "5c93a463d5686a4b126c90151ee87167fa5c2e36",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "28cdf8b4f171846eff4df1045728479e3b2e6178",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "30f494f56445c944dbb830b36924e93778565e70",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "ba8104d78001aac44c90f04b1d6e818cce1340d6",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 32,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "d7f6e83d42c10d2e828fba281ba6d95cedf5dd7a",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 16,
#         "job_failed": 16,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "5eb547f42daa0a9d9446bf53b0e797548d206fd8",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "8859c43dec34718df7bd99dbdc38bca806724ba1",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 32,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "3cf489fcf5c1f4b62fe360b70dcd3d2592f78ef6",
#         "totale_job": 32,
#         "build_uniche": 4,
#         "job_passed": 32,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "85db6289a91201903ec2c717a6b560014fa800d6",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "7208ab786730b3503be85f307d4c0c945c9112d8",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 10,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 20
#     },
#     {
#         "git_trigger_commit": "55d61ebbe599413fb3b5a2b01699a0451f48c96e",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 30,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "b5a26e816c287b680508f287e1ce9d15bff72c8b",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "76021aabcd613065840b69689c08beeefa929fe6",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 30,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "cb445937df12ece03573df751e33c6bf3ca7c841",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "0560149f87c481d8eeb62a3ce3eb2a3c0f66d5c5",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "c3dc2e724b4ba66ce8f262d127d64c3e90335367",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 30,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "d9205873a94303516f98a196421bf7566a35d5bd",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 30,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "2dc800b62eed035ba4f5be3372bed2aa07200dd2",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 30,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "42f7fd335de7026d433271cd27da94d699457270",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 10,
#         "job_failed": 0,
#         "job_canceled": 10,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "8ac54bbaf152b57a3687777a5cc13bab887777bd",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 10,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 20
#     },
#     {
#         "git_trigger_commit": "c34945745dfcac25319a5f0d1837534ebe345788",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 0,
#         "job_failed": 20,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "eefecd2da8ca6a187747d2828cf57ee6c1468c98",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "bf63fcc51effec030001bd5edc36faabb3bd9011",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 30,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "060f13e0a9cc8661414f0ea100d9abafbf125108",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "b35c99c6430a01b6d0110ffba12235cd7e9df09a",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 10,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 20
#     },
#     {
#         "git_trigger_commit": "215cc7bfefe985a4d66e4f709e0a04967faa6df1",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "d26cd6cc27a2fee000e0baaf6fb7553f87807e48",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "4022d8c0e51857b1c574651f0b36f0408a4b1b36",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "a9a5176d78afeef000a441fa12e9287aec6ea621",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 30,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "07eb081e4da8c6ab955bf9b33693d01e8e226645",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 30,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "e698e391e75a96886ea69348bde28fd5b35a6fa6",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 10,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 20
#     },
#     {
#         "git_trigger_commit": "decdbc052966b5af8db4e1c4d3dd214a21d6a25f",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "9c04269d5b98daae7ef5e63b278135ad8936e1a5",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 10,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 20
#     },
#     {
#         "git_trigger_commit": "cee6f8528eede7b3704dc0e35f2c02872179b827",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 10,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "08aceb45c5bc635019163883ac2c21031643eddc",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "d6132d158103fe1e8c29b577a1e601dcfdb7ff8f",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "5984bf47f73a8f11b39d824264ef82b1c9ac9bf4",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "f5f204962f712ec088df3917278873716d87705e",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 10,
#         "job_failed": 0,
#         "job_canceled": 10,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "9e01aa09236ce78bd038ef1591a593e584abe5e3",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "bd9237307cf3f68fc12cae2ec9de661dab96b375",
#         "totale_job": 30,
#         "build_uniche": 3,
#         "job_passed": 20,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 10
#     },
#     {
#         "git_trigger_commit": "bffb84b0bf225e83de16b7c8892fe37ffc29795b",
#         "totale_job": 28,
#         "build_uniche": 4,
#         "job_passed": 28,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "0a1fbab6291627b20765cb15de1d74f4d2d5b30c",
#         "totale_job": 28,
#         "build_uniche": 4,
#         "job_passed": 28,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "f6e2864a92b6ea9dcda799c986fd8831c583742b",
#         "totale_job": 28,
#         "build_uniche": 4,
#         "job_passed": 28,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "610858dab89b58d4da236f9e722e98c64a3c9ad7",
#         "totale_job": 28,
#         "build_uniche": 4,
#         "job_passed": 28,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "66c9465435f1887644955de6bc2bd236d6501f03",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "84f7dc2c695f690772315ec84555b1d2e83cdd89",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "36da9ae6749b74b6f78aeeb3dd038f34907d4594",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "cc6ce4f4e564e16697bd73c83263a045c0ce0985",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "24f1a37ff242df3c7638dae1a13eab1eaa302d62",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "7f03f70d0afb653b91d16e2705a1b50ee9facf2e",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "5987d83b88cba70f57d8319a68b6818edf2e6bda",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "631a86afbe6c52f891f4b5a7c6ccb008502ec688",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 9,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "1f5b80eaeac40c5fe4b8aaefb60dbca1f6ef68a2",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "a3ddab6a92f94c59f0095baf5ffe4e17d0987685",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "c115afad6f48dec60bd939a50d72947771142845",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "353295e8349c26c917317c810e22ec10059d762b",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "693fd38ea487ec38ddfd0b58ff6400f4e8255b90",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "8e60f958a109053699cab91aaae9615af18e1075",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 9,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "90f2d0478a5c98fecd8b3c096c80bae927cfd696",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "fbfe5be259b8c4eb066524f6394bee0e77e16d6b",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 9,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "fa36004ee27fd67f5e683904437116e7c59498b2",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "edc99721ed92815a7260b52eacbdec8113a2dd93",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "eb5c7bd59b181ee971f9a81ec5d9252a87049aed",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "7dd0672fc7c6d5f13afdd24a5768696084c23d57",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "1b0c80e32ab8af06b12b5a7d2a271a33d72fc4aa",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "3ee0193687a2d0d49db6309b627905de85b2da25",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "5664a839d2cc6a8734fcd895df1489911f45e63f",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "b6dc73e1ae05b52527b022ba87d29767d7d8b2ae",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "b867e89f3336631682ae77026d74a54c59ec2521",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 9,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "c3a01877bbae8b888d732aed77e26afa01b82bb4",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "72d508d593f20ef80ffb0dc5e02aed556966e8f8",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "44633e80a7f4c7336d556f3b232052117fa0e65c",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "bf1c9a761af87beaf843c9908b0e6df79d7930f5",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "e6953890734c004ff991c03b552bbdeedf3206fd",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 9,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "c074e2492a3c7fbf2dfd99a9a8867dc414954118",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 0,
#         "job_failed": 9,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "0a3a77679cd00390d09249668af67c468cae1033",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "6e95154824392b6e202f776c17a84d00fefd60b5",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "0a236a579009d6cb162db45cb086c30c34ccc0b5",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "8477bbd83d9c70e2b1e1dca941ab104f33896d60",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 9,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "90e2661ca82ed7609753287c2a0f9761bc14f841",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 9,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "5daa2995513715f2b62e0fda1921aee2a3dd8605",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "427afae14ae4c6a2d32862300d415d07d4f24e4f",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "8f53803f7d49ef0d4ac2fd8bb041ccceea495052",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 0,
#         "job_failed": 9,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "c341cf29c52b350df6a21c25de5b6f170134607c",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "a247d818bc4a6d42d59cdec5902ca9fb7a94d7a9",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "105729b4fc45f1d874e195e589db51f7756f9293",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "750a2f8117154efcc0221960dd51e8493dbcd28b",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "efd30658e28b83fd95c19e1ee4934f09637fd5ed",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "c664c821388c50d718e73848d9ff59df95100c39",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "7b82b17bd4362a5d7ee055da39470fcdf2f063ec",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 9,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "4b468b21da18753ea235c952701e91f09e028d4a",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "2cfd84b30c6df752d7c6b34b41794e76c0cbb56a",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 0,
#         "job_failed": 9,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "a74262910934be550d92edab65934b001880fa6c",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 9,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "8ed90c625152edb85b61e6be10e31604a1f9feb0",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "0207dd07f8e0726ca0683147430e003c82ac9ec9",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 9,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "f0b6d55e944e42a59b729caa4c535f848c5c0aa1",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "bc89c7dbd02730bd6a90555b13759b90a6bc5631",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "9f1d46b9be74f7b66a17d34f3bb54e967a943577",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "eba217b2b552d96b82f6233929bb6907f499fb0f",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "319f3ce09c723ee21af15e591e72d666af1fdacf",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "77ea80e45a4635234f8f68fbadd1a3d7498ed42d",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "9be2c832cd9dde113116dd6f73a1f3a13939834e",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 0,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 27
#     },
#     {
#         "git_trigger_commit": "7d79e2f715373f20cdd565feb762365e3928a2d0",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "62f801362a08bbb13f32a194070ddd22e6badad6",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "d49c2be44ebcd3d0aa18565bd694669f0b5da0db",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "03476bfaee8b537ba35148fb4894089f7e1fb136",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 27,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "6368f36f34ea5b2abcbc287f4d56690503cf54f8",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 18,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 9
#     },
#     {
#         "git_trigger_commit": "a7371a09a447714290de977ad02c7e97de559703",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 0,
#         "job_failed": 0,
#         "job_canceled": 9,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "2b878e2826ac07a5104a755b7648659f55116fbc",
#         "totale_job": 27,
#         "build_uniche": 3,
#         "job_passed": 9,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 18
#     },
#     {
#         "git_trigger_commit": "2a4f481c49461614abc7a6d7f0c050fb612d693f",
#         "totale_job": 24,
#         "build_uniche": 3,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "ff5f6ecf20d5f38906004beb0dce2a9a3d4785ba",
#         "totale_job": 24,
#         "build_uniche": 3,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "a8e2b46af4f07732e30bba69ce49ed180adbe3ec",
#         "totale_job": 24,
#         "build_uniche": 3,
#         "job_passed": 16,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "d13380d0d1660eddeeb29e885e984f1c4372eaa8",
#         "totale_job": 24,
#         "build_uniche": 3,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "42f9583ea4ea0c43076bfa36b0f1b5a6c5e20259",
#         "totale_job": 24,
#         "build_uniche": 3,
#         "job_passed": 8,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 16
#     },
#     {
#         "git_trigger_commit": "9c7ac46111b3d8146346bebe483b6277ff395523",
#         "totale_job": 24,
#         "build_uniche": 3,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "7fc3afedb36d6c5b73e0da6b451c935b84b1b7f5",
#         "totale_job": 24,
#         "build_uniche": 3,
#         "job_passed": 16,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 8
#     },
#     {
#         "git_trigger_commit": "728f15dcaffe9e2cbe5c75441e24924eff478b1d",
#         "totale_job": 24,
#         "build_uniche": 3,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "f6b855b24c1158c48d7675091f00d3419d2d40f8",
#         "totale_job": 24,
#         "build_uniche": 3,
#         "job_passed": 8,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 16
#     },
#     {
#         "git_trigger_commit": "e44e11cc32c600b6214edb2c38d4197b3a426b3a",
#         "totale_job": 24,
#         "build_uniche": 3,
#         "job_passed": 24,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "9bff4e2712a219c907662ba72e1dfe0d43bba5d6",
#         "totale_job": 24,
#         "build_uniche": 3,
#         "job_passed": 8,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 16
#     },
#     {
# ...
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "af91e6da787a870db7b1411a5eacb31893b11ea6",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "753038e4c2cf350b412976f3043cb5c04811a486",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "1a92ca0b06ef5e0b9ae4fdcc38573ee47cd3cf07",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "cf2d89f7f31593a761aeb2d9eb48222e882f40e0",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "1aa7223b9a3e4daf95d35a3dad0e86f6c8c01a2f",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "85106f7af8310444a459a76146f8a21f123c5537",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "59719d5be5f6ddf418de2018b68a8fe244aa0e06",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "2a2b15caca278cb590b66bc3e60b70fed4f53a7f",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "8e108093c0454fb6a8847395d9f4c3d217d759fe",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "45080a569ad468fee2b9e852bccbf31be406ac0e",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "29be4d0f10454577a6c0ff3a7af35c8b13379891",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "641ed8b3355b7d91888e36b487a2309a449886b6",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "238dd85e74d7748d517abdefadfd1082fd4c279b",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "80f923aa4300fcef590b405edade97f7b0517968",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "51c4dd268375fe0def3f0c59cf89791a528e2cf8",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "e76c2c133ab978f9440fbc7b01beb6e53cdcc879",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "c08673969aeffa791546599ecd0a27ce90986e79",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "c82711c30dc49f6ca3d0b7dd5a849362c8c26f07",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "37c4d206c43c3e090b56821e47a461bc72a3a01a",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "21224d3493575bd6b7c0a5e257577a1b5dd1690f",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "82910b2bc6923fae4d65f28410f17b62dc1adaf6",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "992556bbd992a4a324ed2f0a964c67b4b628b9ed",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "dc880219d6e2e7341fbe0fa71c65f3495b936ea2",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "dcb591ac487a9282d9a2dbba55fc607fd295acca",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "9f28df1d429c2e479b007e88abfa5342f1e80060",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "d6c6d78d157251238dcbc2fcdd7268ba9596ee5a",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "368aa48dff9fa8655e27b0b384b579a0b0814af4",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "ffb3c8dd172e358da11edd2abdcd14ceff7e505a",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "2f7e4e1df71e45edd6a9ce9fde3094b1d0a9b05c",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "8dc80555e264bdab8f6a6b8bddb10ce6e3fbd794",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "1e37e46fe5b79e759f7ae0430fdb4c2996c73b05",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "49f52331b271973111b460cd90241877852a6f0f",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "34ea132015707325c9f1926f441b5b8c9b0b0261",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "887e9ae143782d45871efd13c46661f5c99ee15e",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "5de70acf59a352544f1fcdd05bd51ff1876b0215",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "75cb1e9d6663b5082497a932317e42aa0329cac5",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "ee080a1c31d6e67209dc26370041a240b30e81f2",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "fc84c52c0edcb7c495a51a57f90fd38735dab101",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "3962e4d15394ba1a307ff61ded04714fc194185c",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "b2732394a1a4c7d0533f84e301c662a56cb78fe9",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "5965e6f4fae98f545991935fdcee37aecaf7a8af",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "8b6b01b11c610c138497577bd7d881da5956354b",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "aa06e60bafedd086172e7dc57ebf4c7d629a4592",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "50fe1e133f8530c05661421f8d548ba79e0220d6",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "fc07a4c974e9b93599f0af801966f0cc756b2e3c",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "d0c49d1630a7bed25575bf47f69eeeaa1371e276",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "096145c73e5f63a798dc7957a74d9e4ab822787f",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "fc15509c10c3623b591fe2b12679c77b79b95b9f",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "fc3a153cca6f8e9c878e9a74c781aa91ade19504",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "1770ee09640ca4f5b4b619c040ed0c7f1895a5c4",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "d33a4896fc52060eaa01b71990ae209118a479fc",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "1db65d4dd9ed105d069878c271c9a79201e1d3cd",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "0f909bf2fd4f341a74bc68978f5c8283195dbd62",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "3c6a8c6e2bc09548f55b7308bfea39292e078451",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "e3601f2f11bedabd7b53d6c8332675dcd689e1d7",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "5c0256bab50442da0451326a33b2746e84431a57",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "36e4e934671c11f8c65d7452e4eb7fdc3c600c29",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "1eb5271ed2d6ac2ec72f7cd5c578bda3e078a3be",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "f5dfe7b0510b2cb63bf30a5315f51412097ec07d",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "9dde396016a98049f83bbc898f8cfd6fe9da8ec2",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "fcf86b4fdbc50979621addeb52a07168f61d26db",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "f327092ccd81d33dbe288a93b4fb302031d204ff",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "c18eb3edf95df7f39a9f523b81a35b78194ba076",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "5e7de16f59450061227d4103f64e351d1f93d9e9",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "193f37641de537cb9f0af663a58b2475969c2622",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     },
#     {
#         "git_trigger_commit": "a26b2d0c4c7da8157f8015f94c6b1a63d52f73f8",
#         "totale_job": 1,
#         "build_uniche": 1,
#         "job_passed": 1,
#         "job_failed": 0,
#         "job_canceled": 0,
#         "job_errored": 0
#     }
# ]

# %%
import polars as pl
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'
PROJECT_NAME = "SonarSource/sonar-java"

print("Estrazione dei tempi di feedback umano (Restart Delay)...")

# 1. Estrazione dati di base.
#    Fix 6: schema_overrides + cast strict=False per robustezza sul parsing di buildduration.
#    Aggiunto tr_status per identificare le build "cattive" (>=1 job failed/errored).
df = (
    pl.scan_csv(file_path, null_values=["NA", ""], infer_schema_length=10000,
                schema_overrides={"tr_log_buildduration": pl.String})
    .filter(pl.col("gh_project_name") == PROJECT_NAME)
    .select(["git_trigger_commit", "tr_build_id", "gh_build_started_at", "tr_log_buildduration", "tr_status"])
    .drop_nulls(subset=["git_trigger_commit", "tr_build_id", "gh_build_started_at"])
    .with_columns([
        pl.col("tr_log_buildduration").cast(pl.Float64, strict=False),
        (pl.col("gh_build_started_at").str.to_datetime(strict=False).dt.timestamp("ms") / 1000.0).alias("start_ts")
    ])
).collect()

# 2. Raggruppamento per singola build, con flag di build "cattiva".
df_builds = (
    df.group_by(["git_trigger_commit", "tr_build_id"])
    .agg([
        pl.col("start_ts").min().alias("build_start"),
        pl.col("tr_log_buildduration").max().alias("max_duration"),  # la build finisce col job piu' lungo
        ((pl.col("tr_status") == "failed") | (pl.col("tr_status") == "errored")).sum().alias("bad_jobs_count")
    ])
    .with_columns([
        # durata mancante (build interamente errored) -> fine ~ inizio
        (pl.col("build_start") + pl.col("max_duration").fill_null(0.0)).alias("build_end"),
        (pl.col("bad_jobs_count") > 0).alias("is_bad_build")
    ])
    .sort(["git_trigger_commit", "build_start"])
)

# 3. Gap tra questa build e la successiva (stesso commit).
#    Fix 3: il feedback umano avviene solo DOPO un fallimento -> teniamo solo i gap
#    in cui la build CORRENTE (da cui parte il gap) e' "cattiva".
df_feedback = (
    df_builds
    .with_columns(
        pl.col("build_start").shift(-1).over("git_trigger_commit").alias("next_build_start")
    )
    .with_columns(
        (pl.col("next_build_start") - pl.col("build_end")).alias("feedback_time")
    )
    .filter((pl.col("feedback_time") > 0) & (pl.col("is_bad_build") == True))
)

feedback_times = df_feedback["feedback_time"].to_numpy()
print(f"Trovati {len(feedback_times)} eventi di 'Restart' umano validi (solo dopo fallimenti).")

# Rimuoviamo gli outlier estremi (restart entro 48 ore = 172800 secondi)
feedback_times = feedback_times[feedback_times < 172800]

# Fix 1: il simulatore interpreta la lognormale in MINUTI (delay_minutes * 60),
# quindi il fit va fatto sui tempi espressi in MINUTI.
feedback_min = feedback_times / 60.0

# 4. Fitting Statistico (Lognormale sui tempi in minuti)
shape_h, loc_h, scale_h = stats.lognorm.fit(feedback_min, floc=0)

# Stampa Parametri per config.json (human_feedback)
print("\n--- PARAMETRI DEL NODO DI RITARDO UMANO (in MINUTI) ---")
print(f"Distribuzione:         Lognormale")
print(f"sigma_delay (shape):   {shape_h:.4f}")
print(f"scale (mediana, min):  {scale_h:.4f}")
print(f"mu_delay = ln(scale):  {np.log(scale_h):.4f}")
print(f"Media teorica:         {scale_h * np.exp((shape_h**2)/2):.2f} minuti")

# 5. Visualizzazione (in minuti)
plt.figure(figsize=(10, 5))
plt.hist(feedback_min, bins=60, density=True, alpha=0.6, color='#27ae60', label='Dati Reali (Feedback Time)')
x = np.linspace(0, max(feedback_min), 300)
plt.plot(x, stats.lognorm.pdf(x, shape_h, loc_h, scale_h), 'k--', lw=2, label='Fit Lognormale')
plt.title("Tempo di Reazione Umano ai Fallimenti (Think Time)", fontsize=13, fontweight='bold')
plt.xlabel("Ritardo (Minuti)", fontsize=11)
plt.ylabel("Densita'", fontsize=11)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Estrazione dei tempi di feedback umano (Restart Delay)...
# Trovati 330 eventi di 'Restart' umano validi (solo dopo fallimenti).
#
# --- PARAMETRI DEL NODO DI RITARDO UMANO (in MINUTI) ---
# Distribuzione:         Lognormale
# sigma_delay (shape):   2.1384
# scale (mediana, min):  2.6049
# mu_delay = ln(scale):  0.9574
# Media teorica:         25.63 minuti

# %%
import polars as pl
import numpy as np
import scipy.stats as stats

file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'
PROJECT_NAME = "SonarSource/sonar-java"

print("--- 1. CALCOLO PROBABILITA' STATI DEI JOB ---")

# Fix 5: le probabilita' di routing si calcolano su TUTTI i job del progetto, senza
# drop_nulls su colonne non pertinenti (commit/timestamp) che altererebbero i denominatori.
df_routing = (
    pl.scan_csv(file_path, null_values=["NA", ""], infer_schema_length=10000)
    .filter(pl.col("gh_project_name") == PROJECT_NAME)
    .select(["tr_status"])
    .drop_nulls()
).collect()

total_jobs = df_routing.height
df_probs = (
    df_routing.group_by("tr_status")
    .agg(pl.len().alias("count"))
    .with_columns(((pl.col("count") / total_jobs)).alias("probabilita"))
    .sort("probabilita", descending=True)
)
print(f"Totale job analizzati: {total_jobs}")
print(df_probs)

print("\n--- 2. RICALCOLO TEMPI DI INTER-ARRIVO (SOLO NUOVI ARRIVI) ---")

# Per gli inter-arrivi servono commit e timestamp: qui il drop_nulls e' legittimo.
df_jobs = (
    pl.scan_csv(file_path, null_values=["NA", ""], infer_schema_length=10000)
    .filter(pl.col("gh_project_name") == PROJECT_NAME)
    .select(["tr_build_id", "tr_job_id", "git_trigger_commit", "gh_build_started_at", "tr_status"])
    .drop_nulls()
    .with_columns([
        (pl.col("gh_build_started_at").str.to_datetime(strict=False).dt.timestamp("ms") / 1000.0).alias("start_ts")
    ])
).collect()

# Raggruppiamo i job in build per capire lo stato globale della matrice
df_builds = (
    df_jobs.group_by(["tr_build_id", "git_trigger_commit"])
    .agg([
        pl.col("start_ts").min().alias("build_start"),
        ((pl.col("tr_status") == "failed") | (pl.col("tr_status") == "errored")).sum().alias("bad_jobs_count")
    ])
    .with_columns([
        (pl.col("bad_jobs_count") > 0).alias("is_bad_build")
    ])
    .sort(["git_trigger_commit", "build_start"])
)

# Identifichiamo i veri "Nuovi Arrivi": prima build del commit, o build dopo una PASSATA.
df_builds_filtered = (
    df_builds
    .with_columns([
        pl.col("is_bad_build").shift(1).over("git_trigger_commit").alias("prev_build_bad")
    ])
    .with_columns([
        (pl.col("prev_build_bad").is_null() | (pl.col("prev_build_bad") == False)).alias("is_new_arrival")
    ])
)

new_arrivals_ts = (
    df_builds_filtered
    .filter(pl.col("is_new_arrival") == True)
    .sort("build_start")
)["build_start"].to_numpy()

inter_arrivi = np.diff(new_arrivals_ts)
inter_arrivi = inter_arrivi[inter_arrivi > 0]

loc_a, scale_a = stats.expon.fit(inter_arrivi, floc=0)
D_arr, p_arr = stats.kstest(inter_arrivi, 'expon', args=(loc_a, scale_a))

print(f"Build totali: {df_builds.height}")
print(f"Nuovi arrivi effettivi (filtrati i riavvii manuali): {len(new_arrivals_ts)}")
print(f"\n--- FIT ESPONENZIALE (Traffico Esogeno) ---")
print(f"Scale (1/lambda, Media inter-arrivo): {scale_a:.2f} secondi")
print(f"Tasso lambda (Arrivi al secondo):     {1/scale_a:.6f}")
print(f"KS-Test Errore (D):                   {D_arr:.4f}")
# Out:
# --- 1. CALCOLO PROBABILITA' STATI DEI JOB ---
# Totale job analizzati: 16278
# shape: (4, 3)
# ┌───────────┬───────┬─────────────┐
# │ tr_status ┆ count ┆ probabilita │
# │ ---       ┆ ---   ┆ ---         │
# │ str       ┆ u32   ┆ f64         │
# ╞═══════════╪═══════╪═════════════╡
# │ passed    ┆ 12590 ┆ 0.773437    │
# │ errored   ┆ 2935  ┆ 0.180305    │
# │ failed    ┆ 562   ┆ 0.034525    │
# │ canceled  ┆ 191   ┆ 0.011734    │
# └───────────┴───────┴─────────────┘
#
# --- 2. RICALCOLO TEMPI DI INTER-ARRIVO (SOLO NUOVI ARRIVI) ---
# Build totali: 2278
# Nuovi arrivi effettivi (filtrati i riavvii manuali): 1903
#
# --- FIT ESPONENZIALE (Traffico Esogeno) ---
# Scale (1/lambda, Media inter-arrivo): 21797.39 secondi
# Tasso lambda (Arrivi al secondo):     0.000046
# KS-Test Errore (D):                   0.3703

# %%
import polars as pl

file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'
PROJECT_NAME = "SonarSource/sonar-java"

print(f"--- CALCOLO PROBABILITA' DI RETRY (VERO) PER {PROJECT_NAME} ---\n")

# 1. Caricamento. Fix 2: NON richiediamo tr_log_buildduration nel drop_nulls, altrimenti
#    si scarterebbe l'87% dei job errored (che non hanno buildduration). Fix 6: schema robusto.
df = (
    pl.scan_csv(file_path, null_values=["NA", ""], infer_schema_length=10000,
                schema_overrides={"tr_log_buildduration": pl.String})
    .filter(pl.col("gh_project_name") == PROJECT_NAME)
    .select(["tr_build_id", "tr_job_id", "git_trigger_commit", "gh_build_started_at", "tr_status", "tr_log_buildduration"])
    .drop_nulls(subset=["gh_build_started_at", "git_trigger_commit"])
    .with_columns([
        pl.col("tr_log_buildduration").cast(pl.Float64, strict=False),
        (pl.col("gh_build_started_at").str.to_datetime(strict=False).dt.timestamp("ms") / 1000.0).alias("start_ts")
    ])
    .with_columns([
        # end_ts = morte del job; buildduration mancante (errori infra) -> durata 0
        (pl.col("start_ts") + pl.col("tr_log_buildduration").fill_null(0.0)).alias("end_ts")
    ])
).collect()

# 2. Ultimo avvio in assoluto per un dato commit
df_max_start = (
    df.group_by("git_trigger_commit")
    .agg(pl.col("start_ts").max().alias("ultimo_avvio_del_commit"))
)

# 3. Un VERO retry: esiste un avvio successivo sullo stesso commit dopo la morte del job (+10s margine)
df_retry = (
    df.join(df_max_start, on="git_trigger_commit")
    .with_columns([
        (pl.col("ultimo_avvio_del_commit") > (pl.col("end_ts") + 10)).alias("is_retried")
    ])
)

# 4. Probabilita' per stato
stati_anomali = ["failed", "errored"]

for stato in stati_anomali:
    df_stato = df_retry.filter(pl.col("tr_status") == stato)
    totale = df_stato.height
    retried = df_stato.filter(pl.col("is_retried") == True).height

    if totale > 0:
        p_retry = retried / totale
        p_abbandono = 1.0 - p_retry

        print(f"Stato [{stato.upper()}]:")
        print(f"  Totale occorrenze:   {totale}")
        print(f"  Di cui riavviate:    {retried}")
        print(f"  -> Probabilita' di Retry VERO (Feedback): {p_retry:.4f} ({p_retry*100:.2f}%)")
        print(f"  -> Probabilita' di Abbandono (Sink): {p_abbandono:.4f} ({p_abbandono*100:.2f}%)\n")
# Out:
# --- CALCOLO PROBABILITA' DI RETRY (VERO) PER SonarSource/sonar-java ---
#
# Stato [FAILED]:
#   Totale occorrenze:   562
#   Di cui riavviate:    187
#   -> Probabilita' di Retry VERO (Feedback): 0.3327 (33.27%)
#   -> Probabilita' di Abbandono (Sink): 0.6673 (66.73%)
#
# Stato [ERRORED]:
#   Totale occorrenze:   2935
#   Di cui riavviate:    2535
#   -> Probabilita' di Retry VERO (Feedback): 0.8637 (86.37%)
#   -> Probabilita' di Abbandono (Sink): 0.1363 (13.63%)

# %%
import polars as pl

file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'
PROJECT_NAME = "SonarSource/sonar-java"

print(f"--- ESTRAZIONE PMF: DIMENSIONE DEL BATCH (JOB PER BUILD) PER {PROJECT_NAME} ---\n")

# 1. Caricamento dati e conteggio dei job per ogni singola build
df_builds = (
    pl.scan_csv(file_path, null_values=["NA", ""], infer_schema_length=10000)
    .filter(pl.col("gh_project_name") == PROJECT_NAME)
    .select(["tr_build_id", "tr_job_id"])
    .drop_nulls()
    # Raggruppiamo per build e contiamo quanti job contiene
    .group_by("tr_build_id")
    .agg(pl.len().alias("jobs_per_build"))
).collect()

total_builds = df_builds.height

# 2. Calcolo della Probability Mass Function (PMF)
df_pmf = (
    df_builds
    .group_by("jobs_per_build")
    .agg(pl.len().alias("frequenza_assoluta"))
    .with_columns([
        # Calcolo probabilità (0-1) utile per il simulatore
        (pl.col("frequenza_assoluta") / total_builds).round(4).alias("probabilità"),
        # Calcolo percentuale per la stesura del report
        ((pl.col("frequenza_assoluta") / total_builds) * 100).round(2).alias("percentuale_%")
    ])
    # Ordiniamo dal numero di job più piccolo al più grande
    .sort("jobs_per_build")
)

print(f"Totale build analizzate: {total_builds}\n")
print("Probability Mass Function (PMF) della dimensione del batch:")

# Impostiamo il limite di visualizzazione di Polars per vedere tutta la tabella
pl.Config.set_tbl_rows(30)
print(df_pmf)
# Out:
# --- ESTRAZIONE PMF: DIMENSIONE DEL BATCH (JOB PER BUILD) PER SonarSource/sonar-java ---
#
# Totale build analizzate: 2278
#
# Probability Mass Function (PMF) della dimensione del batch:
# shape: (9, 4)
# ┌────────────────┬────────────────────┬─────────────┬───────────────┐
# │ jobs_per_build ┆ frequenza_assoluta ┆ probabilità ┆ percentuale_% │
# │ ---            ┆ ---                ┆ ---         ┆ ---           │
# │ u32            ┆ u32                ┆ f64         ┆ f64           │
# ╞════════════════╪════════════════════╪═════════════╪═══════════════╡
# │ 1              ┆ 97                 ┆ 0.0426      ┆ 4.26          │
# │ 2              ┆ 43                 ┆ 0.0189      ┆ 1.89          │
# │ 3              ┆ 104                ┆ 0.0457      ┆ 4.57          │
# │ 4              ┆ 172                ┆ 0.0755      ┆ 7.55          │
# │ 6              ┆ 241                ┆ 0.1058      ┆ 10.58         │
# │ 7              ┆ 178                ┆ 0.0781      ┆ 7.81          │
# │ 8              ┆ 790                ┆ 0.3468      ┆ 34.68         │
# │ 9              ┆ 447                ┆ 0.1962      ┆ 19.62         │
# │ 10             ┆ 206                ┆ 0.0904      ┆ 9.04          │
# └────────────────┴────────────────────┴─────────────┴───────────────┘

# %%
import polars as pl

file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'
PROJECT_NAME = "SonarSource/sonar-java"

print(f"--- MODELLO ERRORED BIMODALE: prob. di errore PRECOCE per {PROJECT_NAME} ---\n")

# Un job 'errored' e' PRECOCE se ha rotto prima della fase di build -> nessuna
# buildduration registrata (errore di setup/install/dipendenze). E' TARDIVO se ha
# girato l'intero build e poi e' andato in errore -> buildduration presente (~ passed).
df_err = (
    pl.scan_csv(file_path, null_values=["NA", ""], infer_schema_length=10000,
                schema_overrides={"tr_log_buildduration": pl.String})
    .filter((pl.col("gh_project_name") == PROJECT_NAME) & (pl.col("tr_status") == "errored"))
    .select(["tr_log_buildduration"])
    .with_columns(pl.col("tr_log_buildduration").cast(pl.Float64, strict=False))
).collect()

n_tot = df_err.height
n_late = df_err.filter(pl.col("tr_log_buildduration").is_not_null()).height
n_early = n_tot - n_late
p_errored_early = n_early / n_tot if n_tot else float("nan")
media_late = df_err["tr_log_buildduration"].drop_nulls().mean()

print(f"Job errored totali:          {n_tot}")
print(f"  errore PRECOCE (no durata):{n_early:6d}  ({100*n_early/n_tot:.2f}%)")
print(f"  errore TARDIVO (con durata):{n_late:5d}  (media {media_late:.1f} s, ~ come 'passed')")
print(f"\n[config.json] routing.p_errored_early = {p_errored_early:.4f}")

# %%
import polars as pl
import numpy as np

file_path = '/content/drive/MyDrive/Colab Notebooks/PMCSN/TravisTorrent.csv'
PROJECT_NAME = "SonarSource/sonar-java"

print(f"--- SERVIZIO FAILED / CANCELED: lognormale (metodo dei momenti) per {PROJECT_NAME} ---\n")

# Le durate di failed/canceled non sono esattamente lognormali (coda pesante): un fit MLE
# sovrastimerebbe la MEDIA una volta campionata. Si usa il METODO DEI MOMENTI, che sceglie
# mu, sigma per far combaciare media e varianza empiriche -> media simulata corretta.
df = (
    pl.scan_csv(file_path, null_values=["NA", ""], infer_schema_length=10000,
                schema_overrides={"tr_log_buildduration": pl.String, "tr_log_setup_time": pl.String})
    .filter(pl.col("gh_project_name") == PROJECT_NAME)
    .select(["tr_status", "tr_log_setup_time", "tr_log_buildduration"])
    .with_columns([
        pl.col("tr_log_setup_time").cast(pl.Float64, strict=False),
        pl.col("tr_log_buildduration").cast(pl.Float64, strict=False),
    ])
    .drop_nulls()
    .with_columns((pl.col("tr_log_buildduration") - pl.col("tr_log_setup_time")).alias("net"))
    .collect()
)

def lognorm_mom(x):
    m = x.mean()
    v = x.var(ddof=1)
    s2 = np.log(1.0 + v / m**2)
    return np.log(m) - s2 / 2.0, np.sqrt(s2)   # (mu, sigma)

for stato, sez in [("failed", "service_failed"), ("canceled", "service_canceled")]:
    net = df.filter((pl.col("tr_status") == stato) & (pl.col("net") > 0))["net"].to_numpy()
    mu, sigma = lognorm_mom(net)
    print(f"[{stato}] n={len(net)}  media empirica={net.mean():.1f} s")
    print(f"  [config.json] {sez}: mu = {mu:.4f}   sigma = {sigma:.4f}\n")
